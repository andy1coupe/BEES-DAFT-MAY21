# %% [markdown]
# # Andys Jupyter notebook

# %% [markdown]
# **Andy**

# %% [markdown]
# - one dash and space before for bullet point

# %%
name = input("what is your name? ")
# Out:
# what is your name? Andy

# %%
print(name)
# Out:
# Andy

# %% [markdown]
# ![IMG-20170320-WA0030%20%281%29.jpg](attachment:IMG-20170320-WA0030%20%281%29.jpg)

# %%
favourite_holiday = input("what is your favourite holiday?:")
print(favourite_holiday)

# %%
top_activities = input('what are your top 3 things to do on holiday?:')
print(top_activities)

# %% [markdown]
# ## Their favourite things to do are:
# - Sun
# - Sea
# - Sand

# %% [markdown]
# <div>
# <img src="https://cdn.getyourguide.com/img/location/5b45f54dcfce2.jpeg/68.jpg" width="500"/>
# </div>

# %%
from IPython.display import YouTubeVideo

YouTubeVideo('3PEXXwJzzSI', width=800, height=300)
